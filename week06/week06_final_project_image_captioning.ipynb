# %% [markdown]
# # Image Captioning Final Project
#
# In this final project you will define and train an image-to-caption model, that can produce descriptions for real world images!
#
# <img src="images/encoder_decoder.png" style="width:70%">
#
# Model architecture: CNN encoder and RNN decoder.
# (https://research.googleblog.com/2014/11/a-picture-is-worth-thousand-coherent.html)

# %% [markdown]
# Alright, here's our plan:
# * Take a pre-trained inception v3 to vectorize images
# * Stack an LSTM on top of it
# * Train the thing on MSCOCO

# %% [markdown]
# ## Importing stuff and preparing data

# %%
# %%bash
#
# # shred -u setup_colab.py
#
# # wget https://raw.githubusercontent.com/hse-aml/intro-to-dl-pytorch/main/utils/setup_colab.py -O setup_colab.py

# %%
import setup_colab

# setup_colab.setup_week06()

# %%
import grading
import grading_utils

grader = grading.Grader(
    assignment_key="NEDBg6CgEee8nQ6uE8a7OA",
    all_parts=["19Wpv", "E2OIL", "rbpnH", "YJR7z"]
)

# %%
# token expires every 30 min
COURSERA_TOKEN = "MNdNG081Zd4C4uGl"
COURSERA_EMAIL = "pavelb23@gmail.com"

# %%
# %%time

# Load dataset (vectorized images and captions)
import numpy as np
import json

img_codes = np.load("data/image_codes.npy")
captions = json.load(open('data/captions_tokenized.json'))
# Out:
# CPU times: user 117 ms, sys: 280 ms, total: 397 ms
# Wall time: 521 ms

# %%
import copy

# %%
print("Each image code is a 2048-unit vector [ shape: %s ]" % str(img_codes.shape))
print(img_codes[0,:10], end='\n\n')
print("For each image there are 5 reference captions, e.g.:\n")
print('\n'.join(captions[0]))
# Out:
# Each image code is a 2048-unit vector [ shape: (118287, 2048) ]
# [0.3659946  0.2016555  0.9245725  0.57063824 0.547268   0.8275868
#  0.3687277  0.12085301 0.0561931  0.49758485]
#
# For each image there are 5 reference captions, e.g.:
#
# people shopping in an open market for vegetables .
# an open market full of people and piles of vegetables .
# people are shopping at an open air produce market .
# large piles of carrots and potatoes at a crowded outdoor market .
# people shop for vegetables like carrots and potatoes at an open air market .

# %% [markdown]
# As you can see, all captions are already tokenized and lowercased. We now want to split them and add some special tokens for start/end of caption.

# %%
# split descriptions into tokens
for img_i in range(len(captions)):
    for caption_i in range(len(captions[img_i])):
        sentence = captions[img_i][caption_i] 
        captions[img_i][caption_i] = ["#START#"] + sentence.split(' ') + ["#END#"]

# %% [markdown]
# You don't want your network to predict a million-size vector of probabilities at each step, so we're gotta make some cuts.
#
# We want you to count the occurences of each word so that we can decide which words to keep in our vocabulary.

# %%
# Build a Vocabulary
from collections import Counter
word_counts = Counter()

# Compute word frequencies for each word in captions. See code above for data structure

for imgs in captions:
    for sentence in imgs:
        for word in sentence:
            word_counts[word]+=1
# YOUR CODE HERE

# %%
vocab  = ['#UNK#', '#START#', '#END#', '#PAD#']
vocab += [k for k, v in word_counts.items() if v >= 5 if k not in vocab]
n_tokens = len(vocab)

assert 10000 <= n_tokens <= 10500

word_to_index = {w: i for i, w in enumerate(vocab)}

# %%
## GRADED PART, DO NOT CHANGE!
grader.set_answer("19Wpv", grading_utils.test_vocab(vocab))

# %%
# you can make submission with answers so far to check yourself at this stage
# grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %%
eos_ix = word_to_index['#END#']
unk_ix = word_to_index['#UNK#']
pad_ix = word_to_index['#PAD#']

def as_matrix(sequences, max_len=None):
    """ Convert a list of tokens into a matrix with padding """
    max_len = max_len or max(map(len,sequences))
    
    matrix = np.zeros((len(sequences), max_len), dtype='int32') + pad_ix
    for i,seq in enumerate(sequences):
        row_ix = [word_to_index.get(word, unk_ix) for word in seq[:max_len]]
        matrix[i, :len(row_ix)] = row_ix
    
    return matrix

# %%
# Try it out on several descriptions of a random image
as_matrix(captions[1337])
# Out:
# array([[   1,   24,  262,  140,    6,  159,   14,   24,  858,  155,   12,
#            2,    3,    3,    3,    3,    3,    3,    3],
#        [   1,   24,  262,   53,   18,   24,  858,  155,    2,    3,    3,
#            3,    3,    3,    3,    3,    3,    3,    3],
#        [   1,   24,  262,   41,   18,  903,   35,  620,  155,    2,    3,
#            3,    3,    3,    3,    3,    3,    3,    3],
#        [   1,   45,  115,  262,   41,   53,   18,  620, 1525,   77,   12,
#            2,    3,    3,    3,    3,    3,    3,    3],
#        [   1,   24,  262,   53,   18,   24,  858,  123,   58,   45,  276,
#         3641,   24, 3642,   35,   45, 1128,   12,    2]], dtype=int32)

# %% [markdown]
# ## Building our neural network
# As we mentioned earlier, we shall build an rnn "language-model" conditioned on vectors from the convolutional part.
#
# <img src="https://github.com/yunjey/pytorch-tutorial/raw/master/tutorials/03-advanced/image_captioning/png/model.png" style="width:70%">

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
class CaptionNet(nn.Module):
    
    def __init__(self, n_tokens=n_tokens, emb_size=128, lstm_units=256, cnn_feature_size=2048, num_layers=1):
        """ A recurrent 'head' network for image captioning. See scheme above. """
        super().__init__()
        
        # a layer that converts conv features to initial_h (h_0) and initial_c (c_0)
        self.cnn_to_h0 = nn.Linear(cnn_feature_size, lstm_units)
        self.cnn_to_c0 = nn.Linear(cnn_feature_size, lstm_units)

        # create embedding for input words. Use the parameters (e.g. emb_size).
        # YOUR CODE HERE
        self.emb=nn.Embedding(n_tokens, emb_size)
            
        # lstm: create a recurrent core of your network. Use either LSTMCell or just LSTM. 
        # In the latter case (nn.LSTM), make sure batch_first=True
        # YOUR CODE HERE
        self.lstm=nn.LSTM(input_size=emb_size, hidden_size=lstm_units, num_layers=num_layers, batch_first=True)
            
        # create logits: linear layer that takes lstm hidden state as input and computes one number per token
        # YOUR CODE HERE
        self.linear=nn.Linear(in_features=lstm_units, out_features=n_tokens)
        
    def forward(self, image_vectors, captions_ix):
        """ 
        Apply the network in training mode. 
        :param image_vectors: torch tensor containing inception vectors. shape: [batch, cnn_feature_size]
        :param captions_ix: torch tensor containing captions as matrix. shape: [batch, word_i]. 
            padded with pad_ix
        :returns: logits for next token at each tick, shape: [batch, word_i, n_tokens]
        """

        self.lstm.flatten_parameters()

        initial_cell = self.cnn_to_c0(image_vectors)
        initial_hid = self.cnn_to_h0(image_vectors)
        
        # compute embeddings for captions_ix
        # YOUR CODE HERE
        x_emb=self.emb(captions_ix)
        
        # apply recurrent layer to captions_emb. 
        # 1. initialize lstm state with initial_* from above
        # 2. feed it with captions. Mind the dimension order in docstring
        # 3. compute logits for next token probabilities
        # Note: if you used nn.LSTM, you can just give it (initial_cell[None], initial_hid[None]) as second arg
        out, hidden=self.lstm(x_emb, (initial_cell[None], initial_hid[None]))
        

        # lstm_out should be lstm hidden state sequence of shape [batch, caption_length, lstm_units]
        # YOUR CODE HERE
        logits=self.linear(out)
        
        # compute logits from lstm_out
        # YOUR CODE HERE
        # print(logits.shape)
        return logits

# %%
network = CaptionNet(n_tokens)

# %%
dummy_img_vec = torch.randn(len(captions[0]), 2048)
dummy_capt_ix = torch.tensor(as_matrix(captions[0]), dtype=torch.int64)

dummy_logits = network.forward(dummy_img_vec, dummy_capt_ix)

print('shape:', dummy_logits.shape)
assert dummy_logits.shape == (dummy_capt_ix.shape[0], dummy_capt_ix.shape[1], n_tokens)
# Out:
# shape: torch.Size([5, 16, 10403])

# %%
def compute_loss(network, image_vectors, captions_ix):
    """
    :param image_vectors: torch tensor containing inception vectors. shape: [batch, cnn_feature_size]
    :param captions_ix: torch tensor containing captions as matrix. shape: [batch, word_i]. 
        padded with pad_ix
    :returns: crossentropy (neg llh) loss for next captions_ix given previous ones. Scalar float tensor
    """
    
    # captions for input - all except last because we don't know next token for last one.
    captions_ix_inp = captions_ix[:, :-1].contiguous()
    captions_ix_next = captions_ix[:, 1:].contiguous()
        
    # apply the network, get predictions for captions_ix_next
    logits_for_next = network.forward(image_vectors, captions_ix_inp)
    
    # compute the loss function between logits_for_next and captions_ix_next
    # Use the mask!
    # Make sure that predicting next tokens after EOS do not contribute to loss
    # You can do that either by multiplying elementwise loss by (captions_ix_next != pad_ix)
    # or by using ignore_index in some losses.
    
    # YOUR CODE HERE
    criterion=nn.CrossEntropyLoss(ignore_index=pad_ix)
    return criterion(logits_for_next.transpose(1,2), captions_ix_next)

# %%
dummy_loss = compute_loss(network, dummy_img_vec, dummy_capt_ix)

assert len(dummy_loss.shape) <= 1, 'loss must be scalar'
assert dummy_loss.data.numpy() > 0, "did you forget the 'negative' part of negative log-likelihood"

dummy_loss.backward()

assert all(param.grad is not None for param in network.parameters()), \
    'loss should depend differentiably on all neural network weights'

# %%
## GRADED PART, DO NOT CHANGE!
grader.set_answer("rbpnH", grading_utils.test_network(network))

# %%
# you can make submission with answers so far to check yourself at this stage
# grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# ## Batch generator

# %%
from sklearn.model_selection import train_test_split

captions = np.array(captions)
train_img_codes, val_img_codes, train_captions, val_captions = train_test_split(
    img_codes, captions, test_size=0.1, random_state=42
)
# Out:
# /tmp/ipykernel_151443/2956005562.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   captions = np.array(captions)

# %%
from random import choice

def generate_batch(img_codes, captions, batch_size, max_caption_len=None):
    
    # sample random numbers for image/caption indicies
    random_image_ix = np.random.randint(0, len(img_codes), size=batch_size)
    
    # get images
    batch_images = img_codes[random_image_ix]
    
    # 5-7 captions for each image
    captions_for_batch_images = captions[random_image_ix]
    
    # pick one from a set of captions for each image
    batch_captions = list(map(choice,captions_for_batch_images))
    
    # convert to matrix
    batch_captions_ix = as_matrix(batch_captions,max_len=max_caption_len)
    
    return torch.tensor(batch_images, dtype=torch.float32), \
        torch.tensor(batch_captions_ix, dtype=torch.int64)

# %%
generate_batch(img_codes, captions, 3)
# Out:
# (tensor([[0.3425, 0.0788, 0.1396,  ..., 0.1359, 0.2275, 0.2386],
#          [0.8073, 0.1269, 1.3132,  ..., 0.2582, 0.8169, 1.1735],
#          [0.7043, 0.0909, 0.3438,  ..., 0.1507, 0.3973, 0.1195]]),
#  tensor([[   1,   24, 5374,  588,   24, 5885,  588,   15,   24,  189,  588,    2,
#              3],
#          [   1,   45,   71,   41,  663,   58,  477, 5423,   15,  295, 1504,   12,
#              2],
#          [   1,   24,  195,  373,  443,   63,   41,  408,   88,  355,   12,    2,
#              3]]))

# %%
## GRADED PART, DO NOT CHANGE!
grader.set_answer("E2OIL", grading_utils.test_batch(generate_batch(img_codes, captions, 3)))

# %%
# you can make submission with answers so far to check yourself at this stage
# grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# ## Train and validate loop

# %%
from tqdm import tqdm_notebook
from IPython.display import clear_output
from tqdm import tqdm

# %%
DEVICE = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# %%
network = CaptionNet(n_tokens).to(DEVICE)
optimizer = torch.optim.Adam(network.parameters(), lr=1e-3)

batch_size = 128
n_epochs = 100
n_batches_per_epoch = 50
n_validation_batches = 5  # how many batches are used for validation after each epoch

# %%
for epoch in range(n_epochs):
    
    train_loss = 0
    network.train()
    for _ in tqdm(range(n_batches_per_epoch)):
        images, captions = generate_batch(train_img_codes, train_captions, batch_size)
        images = images.to(DEVICE)
        captions = captions.to(DEVICE)

        loss_t = compute_loss(network, images, captions)
        
        # clear old gradients; do a backward pass to get new gradients; then train with opt
        # YOUR CODE HERE
        network.zero_grad()
        loss_t.backward()
        optimizer.step()
        
        train_loss += loss_t.detach().cpu().numpy()
        
    train_loss /= n_batches_per_epoch
    
    val_loss = 0
    network.eval()
    for _ in range(n_validation_batches):
        images, captions = generate_batch(val_img_codes, val_captions, batch_size)
        images = images.to(DEVICE)
        captions = captions.to(DEVICE)
        
        with torch.no_grad():
            loss_t = compute_loss(network, images, captions)

        val_loss += loss_t.detach().cpu().numpy()

    val_loss /= n_validation_batches
    
    clear_output()
    print('\nEpoch: {}, train loss: {}, val loss: {}'.format(epoch, train_loss, val_loss))

print("Finished!")
# Out:
# Epoch: 99, train loss: 2.5271794033050536, val loss: 2.539976215362549
# Finished!

# %%
## GRADED PART, DO NOT CHANGE!
grader.set_answer("YJR7z", val_loss)

# %%
# grader.submit(COURSERA_EMAIL, COURSERA_TOKEN)

# %% [markdown]
# ## Generating caption
#
# The function below creates captions by sampling from probabilities defined by the net.
#
# The implementation used here is simple but inefficient (quadratic in lstm steps). We keep it that way since it isn't a performance bottleneck.

# %%
from beheaded_inception3 import beheaded_inception_v3

inception = beheaded_inception_v3().eval()

def generate_caption(image, caption_prefix = ('#START#',), t=1, sample=True, max_len=100, network=network):
    network = network.cpu().eval()

    assert isinstance(image, np.ndarray) and np.max(image) <= 1\
           and np.min(image) >= 0 and image.shape[-1] == 3
    
    image = torch.tensor(image.transpose([2, 0, 1]), dtype=torch.float32)
    
    vectors_8x8, vectors_neck, logits = inception(image[None])
    caption_prefix = list(caption_prefix)
    
    for _ in range(max_len):
        
        prefix_ix = as_matrix([caption_prefix])
        prefix_ix = torch.tensor(prefix_ix, dtype=torch.int64)
        next_word_logits = network.forward(vectors_neck, prefix_ix)[0, -1]
        next_word_probs = F.softmax(next_word_logits, -1).detach().numpy()
        
        assert len(next_word_probs.shape) == 1, 'probs must be one-dimensional'
        next_word_probs = next_word_probs ** t / np.sum(next_word_probs ** t) # apply temperature

        if sample:
            next_word = np.random.choice(vocab, p=next_word_probs) 
        else:
            next_word = vocab[np.argmax(next_word_probs)]

        caption_prefix.append(next_word)

        if next_word == '#END#':
            break

    return ' '.join(caption_prefix[1:-1])
# Out:
# /home/pavel/miniconda3/envs/deep2/lib/python3.8/site-packages/torchvision/models/inception.py:81: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn('The default weight initialization of inception_v3 will be changed in future releases of '

# %%
import matplotlib.pyplot as plt
from skimage.transform import resize

# sample image
# ! wget https://avatars.mds.yandex.net/get-zen_doc/1578906/pub_5deb7d24a06eaf00af983448_5deb7d6643863f00ae06dc24/scale_1200 -O data/img.jpg

# %%
img = plt.imread('data/img.jpg')
img = resize(img, (299, 299))

plt.imshow(img)

for i in range(5):
    print(generate_caption(img, t=5.))
# Out:
# a cat is sitting on a wooden bench .
# a cat is sitting on a wooden bench .
# a cat sitting on a wooden bench .
# a cat is sitting on a bench .
# a cat is sitting on a bench .

# %% [markdown]
# # Staff graded assignment tasks
#
# Now you are going to train the network and estimate it's quality on checkpoints.
#
# 1. Train the network for 6 epoches (set n_batches_per_epoch to such value, that with batch_size you iterate over the whole dataset at one epoch, you should increase n_validation_batches to validate more accurately), find good and bad annotation examples. What loss values have you achieved?
# 1. Continue training until 12 epoch. What happened to the loss value? Search for examples, that have improved their captions in comparison to 6 epoch training.
# 1. Train the network until convergence. How many epoches do you need?
# 1. Mobile devices are not very powerfull. Try reducing network size (emb_size=64, lstm_units=128), how it affected network quality after 12 epoches in comparison to original network? And visually?
# 1. Collect at least 10 images that you like to test our network on.
#     - Seriously, that's part of an assignment. Go get at least 10 pictures to get captioned
#     - Make sure it works okay on simple images before going to something more complex
#     - Photos, not animation/3d/drawings, unless you want to train CNN network on anime
#     - Mind the aspect ratio
#     - Photos should not be from MSCOCO! Collect some data yourself, take anything you find worth testing on

# %% [markdown]
# ### Training tips
#
# * If training loss has become close to 0 or model produces garbage, double-check that you're predicting next words, not current or t+2'th words
# * If the model generates fluent captions that have nothing to do with the images
#     * this may be due to recurrent net not receiving image vectors.
#     * alternatively it may be caused by gradient explosion, try clipping 'em or just restarting the training
#     * finally, you may just need to train the model a bit more
# * Crossentropy is a poor measure of overfitting
#     * Model can overfit validation crossentropy but keep improving validation quality.
#     * Use human (manual) evaluation or try automated metrics: cider or bleu
#
# * We recommend you to periodically evaluate the network using the next "apply trained model" block
#     * its safe to interrupt training, run a few examples and start training again
# * The typical loss values should be around 3~5 if you average over time, scale by length if you sum over time. The reasonable captions began appearing at loss=2.8 ~ 3.0

# %% [markdown]
# ## Images to test on
#
# We have downloaded 30 images from validation set of MSCOCO, they are located in `data` folder and named `img_i.jpg` for i from 0 to 29. You should use them to measure your network quality during checkpoints.

# %%
### READ IMAGES FROM DISK
mscoco_images=[]
for i in range(30):
    mscoco_image=plt.imread(f'data/img_{i}.jpg')
    mscoco_image=resize(mscoco_image, (500, 500))
    mscoco_images.append(mscoco_image)

# %% [markdown]
# ## First task
#
# Train the network for 6 epoches (set n_batches_per_epoch to such value, that with batch_size you iterate over the whole dataset at one epoch, you should increase n_validation_batches to validate more accurately), find good and bad annotation examples. What loss values have you achieved?

# %%
class EarlyStopping():
    """
    Early stopping to stop the training when the loss does not improve after
    certain epochs.
    """
    def __init__(self, patience=5, min_delta=0):
        """
        :param patience: how many epochs to wait before stopping when loss is
               not improving
        :param min_delta: minimum difference between new loss and old loss for
               new loss to be considered as an improvement
        """
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
    def __call__(self, val_loss):
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            # reset counter if validation loss improves
            self.counter = 0
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            print(f"INFO: Early stopping counter {self.counter} of {self.patience}")
            if self.counter >= self.patience:
                print('INFO: Early stopping')
                self.early_stop = True

# %%
### USE CODE FROM ABOVE (MAIN TRAIN AND VAL LOOP)
def train_network(net, n_epochs, optimizer, batch_size, n_batches_per_epoch, n_validation_batches, epoch_start=0, train_history=None, early_stop=None):
    if train_history is None:
        train_history={}
        train_history['train_loss']=[]
        train_history['val_loss']=[]
    for epoch in range(epoch_start, epoch_start+n_epochs):
        train_loss = 0
        net.train()
        for _ in tqdm(range(n_batches_per_epoch)):
            images, captions = generate_batch(train_img_codes, train_captions, batch_size)
            images = images.to(DEVICE)
            captions = captions.to(DEVICE)

            loss_t = compute_loss(net, images, captions)

            # clear old gradients; do a backward pass to get new gradients; then train with opt
            # YOUR CODE HERE
            net.zero_grad()
            loss_t.backward()
            optimizer.step()

            train_loss += loss_t.detach().cpu().numpy()

        train_loss /= n_batches_per_epoch

        val_loss = 0
        net.eval()
        for _ in range(n_validation_batches):
            images, captions = generate_batch(val_img_codes, val_captions, batch_size)
            images = images.to(DEVICE)
            captions = captions.to(DEVICE)

            with torch.no_grad():
                loss_t = compute_loss(net, images, captions)

            val_loss += loss_t.detach().cpu().numpy()

        val_loss /= n_validation_batches

        clear_output()
        print('\nEpoch: {}, train loss: {}, val loss: {}'.format(epoch, train_loss, val_loss))
        train_history['train_loss'].append(train_loss)
        train_history['val_loss'].append(val_loss)
        if early_stop:
            early_stop(val_loss)
            if early_stop.early_stop:
                break

    print("Finished!")
    return train_history

### USE CODE FROM ABOVE (GENERATING CAPTION FOR IMAGES)

# %%
TOTAL_TRAIN_IMG_COUNT=len(train_img_codes)
TOTAL_VALIDATION_IMG_COUNT=len(val_img_codes)

# %%
batch_size=128
n_batches_per_epoch=TOTAL_TRAIN_IMG_COUNT//batch_size
n_validation_batches=TOTAL_VALIDATION_IMG_COUNT//batch_size

# %%
network_sga = CaptionNet(n_tokens).to(DEVICE)
optimizer = torch.optim.Adam(network_sga.parameters(), lr=1e-3)

# %%
network_sga_history=train_network(network_sga, 6, optimizer, batch_size, n_batches_per_epoch, n_validation_batches)
# Out:
# Epoch: 5, train loss: 2.5251238475207387, val loss: 2.5682755579119143
# Finished!

# %%
def print_train_history(history):
    x=range(len(history['train_loss']))
    plt.figure(figsize=(6,6))
    plt.plot(x, history['train_loss'], label='Train loss')
    plt.plot(x, history['val_loss'], label='Validation loss')
    plt.grid()
    plt.legend()
    plt.title(f'Model trained with {len(history["train_loss"])} epochs')
    plt.show()

# %%
def print_val_img_caption(img_id, network):
    img=mscoco_images[img_id]
    plt.imshow(img)

    for i in range(5):
        print(generate_caption(img, t=5., network=network))

# %%
print_train_history(network_sga_history)

# %%
model_6_epochs=copy.deepcopy(network_sga)

# %% [markdown]
# Good examples of work of network that was trained on 6 epochs
# ---

# %%
print_val_img_caption(1, model_6_epochs)
# Out:
# a black and white photo of a field of grass .
# a black and white photo of a green field .
# a black and white photo of a green field
# a black and white photo of a green field .
# a black and white photo of a tree .

# %%
print_val_img_caption(21, model_6_epochs)
# Out:
# a red and white bus parked in a field .
# a red and white bus parked in a parking lot .
# a red and white bus parked on the side of a road .
# a red and white bus parked on a road .
# a red and white bus parked on the side of a road .

# %% [markdown]
# Bad examples of work of network that was trained on 6 epochs
# ---

# %%
print_val_img_caption(3, model_6_epochs)
# Out:
# a red and white bird sitting on a wooden bench
# a red fire hydrant sitting on a sidewalk next to a tree .
# a vase with a red and blue and white bird sitting on the side of it .
# a red and white fire hydrant sitting on a sidewalk .
# a wooden bench sitting next to a tree .

# %%
print_val_img_caption(9, model_6_epochs)
# Out:
# a bench is sitting in a window sill .
# a bench sitting in the middle of a building .
# a bench sitting in front of a building .
# a bench sitting in the middle of a street .
# a bench sitting on the side of a road .

# %% [markdown]
# ## Second task
#
# Continue training until 12 epoch. What happened to the loss value? Search for examples, that have improved their captions in comparison to 6 epoch training.

# %%
### USE CODE FROM ABOVE (MAIN TRAIN AND VAL LOOP)
### USE CODE FROM ABOVE (GENERATING CAPTION FOR IMAGES)
network_sga_history=train_network(network_sga, 6, optimizer, batch_size, n_batches_per_epoch, n_validation_batches, epoch_start=7, train_history=network_sga_history)
# Out:
# Epoch: 12, train loss: 2.353855770560952, val loss: 2.448627127253491
# Finished!

# %%
print_train_history(network_sga_history)

# %%
model_12_epochs=copy.deepcopy(network_sga)

# %%
print_val_img_caption(9, model_12_epochs)
# Out:
# a man standing next to a fire hydrant .
# a man standing next to a building with a clock on it .
# a man is sitting on a bench in front of a building .
# a fire hydrant in front of a building .
# a man standing next to a fire hydrant .

# %% [markdown]
# ## Third task
#
# Train deep network until convergence. How many epoches do you need?

# %%
### USE CODE FROM ABOVE (MAIN TRAIN AND VAL LOOP)
network_conv_epochs = CaptionNet(n_tokens).to(DEVICE)
optimizer = torch.optim.Adam(network_conv_epochs.parameters(), lr=1e-3)
n_batches_per_epoch=TOTAL_TRAIN_IMG_COUNT//batch_size
n_epoch=100

# %%
early_stop=EarlyStopping(patience=7)
network_sga_history=train_network(network_sga, 100, optimizer, batch_size, n_batches_per_epoch, n_validation_batches, epoch_start=12, train_history=network_sga_history, early_stop=early_stop)
# Out:
# Epoch: 21, train loss: 2.3474191047080875, val loss: 2.4548432930656103
# INFO: Early stopping counter 7 of 7
# INFO: Early stopping
# Finished!

# %%
print_train_history(network_sga_history)

# %%
model_conv=copy.deepcopy(network_sga)

# %% [markdown]
# It took 15 epoch until model is converged and reach minimum of validation loss for 7 epoch.

# %% [markdown]
# ## Fourth task
#
#  Mobile devices are not very powerfull. Try reducing network size (emb_size=64, lstm_units=128), how it affected network quality after 12 epoches in comparison to original network? And visually?

# %%
### USE CODE FROM ABOVE (MAIN TRAIN AND VAL LOOP)
### USE CODE FROM ABOVE (GENERATING CAPTION FOR IMAGES)
mobile_network=CaptionNet(n_tokens, emb_size=64, lstm_units=128).to(DEVICE)
mobile_optimizer = torch.optim.Adam(mobile_network.parameters(), lr=1e-3)

# %%
mobile_history=train_network(mobile_network, 12, mobile_optimizer, batch_size, n_batches_per_epoch, n_validation_batches)
# Out:
# Epoch: 11, train loss: 2.525048397651792, val loss: 2.588587558787802
# Finished!

# %%
print_train_history(mobile_history)

# %% [markdown]
# Validation loss(2.588) for mobile network model is greater than validation loss for converged model(2.4548)

# %%
print_val_img_caption(6, model_conv)
# Out:
# a woman in a bikini and a dog walking across the beach .
# a man in a wet suit holding a surfboard .
# a woman is walking with a frisbee in her hand .
# a woman standing on a beach holding a surfboard .
# a woman standing on a beach holding a surfboard .

# %%
print_val_img_caption(10, model_conv)
# Out:
# a man sitting on a laptop computer while another man looks on .
# a man is sitting on a laptop computer
# a man sitting on a laptop computer while holding a cellphone .
# a man sitting on a laptop computer while a woman is sitting on a bench .
# a man is sitting at a desk with a laptop .

# %%
print_val_img_caption(6, mobile_network)
# Out:
# a woman holding a kite in the air .
# a woman is playing frisbee in the air on a beach .
# a man is holding a kite on the beach .
# a man in a blue shirt and a white shirt holding a frisbee .
# a man in a blue shirt is flying a kite .

# %%
print_val_img_caption(10, mobile_network)
# Out:
# a man sitting on a chair with a laptop .
# a man is sitting on a motorcycle with a helmet .
# a man is sitting on a motorcycle with a red umbrella .
# a man sitting on a motorcycle with a man in a suit .
# a man is sitting on a motorcycle with a man in a suit .

# %% [markdown]
# Some image captures are better for converged full model, some for mobile network model. Reasons for that look like because full model is overfitted and mobile network is underfit.

# %% [markdown]
# ## Fifth task
#
# Collect at least 10 images that you like to test our network on.
#    - Seriously, that's part of an assignment. Go get at least 10 pictures to get captioned
#    - Make sure it works okay on simple images before going to something more complex
#    - Photos, not animation/3d/drawings, unless you want to train CNN network on anime
#    - Mind the aspect ratio
#    - Photos should not be from MSCOCO! Collect some data yourself, take anything you find worth testing on

# %%
### YOUR IMAGES COLLECTING CODE
### YOUR CAPTIONS GENERATING CODE
import skimage.transform as st

# %%
from PIL import Image

# %%
def crop_center(pil_img, crop_width, crop_height):
    img_width, img_height = pil_img.size
    return pil_img.crop(((img_width - crop_width) // 2,
                         (img_height - crop_height) // 2,
                         (img_width + crop_width) // 2,
                         (img_height + crop_height) // 2))

def crop_max_square(pil_img):
    return crop_center(pil_img, min(pil_img.size), min(pil_img.size))

# %%
def print_custom_image(path, network):
    im=crop_max_square(Image.open(path))
    img=resize(np.asarray(im), (500,500))
    plt.imshow(img)
    for i in range(5):
        print(generate_caption(img, t=5., network=network))

# %%
custom_images = !ls val_pictures

# %%
custom_images=[f'val_pictures/{p}' for p in custom_images]

# %%
print_custom_image(custom_images[0], network_sga)
# Out:
# a large clock tower with a clock on top .
# a large clock tower with a clock on top .
# a large clock tower in a cloudy sky .
# a large clock tower with a clock on it .
# a large clock tower with a clock on the side of it .

# %%
print_custom_image(custom_images[1], network_sga)
# Out:
# a group of people standing on a field .
# a group of people are standing on a field .
# a group of people standing on a field .
# a group of people standing on a field .
# a group of people standing on a field .

# %%
print_custom_image(custom_images[2], network_sga)
# Out:
# a person holding a cell phone in front of a building .
# a person holding a cell phone in front of a building .
# a man is holding a cell phone in his hand .
# a person holding a cell phone in their hands .
# a person holding a cell phone in front of a building .

# %%
print_custom_image(custom_images[3], network_sga)
# Out:
# a giraffe in a field with a sky background
# a giraffe in a zoo is on a sunny day .
# a large tree in the middle of a forest .
# a giraffe standing in a field with trees in the background .
# a large tree in a field with a sky background

# %%
print_custom_image(custom_images[4], network_sga)
# Out:
# a red fire hydrant is in the grass .
# a large blue and white airplane sitting on top of a wooden fence .
# a red fire hydrant in the middle of a field .
# a red and white fire hydrant in the grass .
# a red fire hydrant with a red and white stripe .

# %%
print_custom_image(custom_images[5], network_sga)
# Out:
# a large brown bear walking in the grass .
# a large bear is walking through the water .
# a bear is standing in the water .
# a large bear is standing in the water .
# a large brown bear is walking on a rock .

# %%
print_custom_image(custom_images[6], network_sga)
# Out:
# a dog is sitting in a chair with a cat .
# a dog is sitting in a chair with a cat in his lap .
# a dog is sitting on a couch with a cat .
# a dog is sitting in a chair with a cat .
# a dog with a hat on a leash and a dog

# %%
print_custom_image(custom_images[7], network_sga)
# Out:
# a red car is parked in the water .
# a red and white photo of a car and a dog
# a car is parked in a field with a sky background .
# a red and white car and a dog in the grass .
# a red and white dog sitting in the grass

# %%
print_custom_image(custom_images[8], network_sga)
# Out:
# a banana and a banana are sitting on a table .
# a bunch of bananas are on a table
# a bunch of bananas are on a table
# a bunch of bananas are on a table
# a banana with a bunch of bananas on it .

# %%
print_custom_image(custom_images[9], network_sga)
# Out:
# a man is holding a frisbee in his mouth .
# a man is standing on a rock in the water .
# a black and white bird sitting on a rock .
# a man is holding a frisbee in his mouth .
# a black and white bird standing on a sandy beach .
